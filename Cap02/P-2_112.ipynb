# %% [markdown]
# # Problem 2-111 from chapter 02
# ***

# %% [markdown]
# ### A and B are mutually exclusive events. P(A|C) = 1 and P(B|C) = 0.

# %%
from matplotlib_venn import venn3
import matplotlib.pyplot as plt

# %%
venn3(subsets = (5, 10, 0, 0, 5, 0, 0))
plt.show()
