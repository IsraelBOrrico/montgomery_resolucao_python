# %% [markdown]
# # Problem 111 from chapter 02

# %%
from matplotlib_venn import venn2
import matplotlib.pyplot as plt

# %%
venn2(subsets = (20, 0, 4))
plt.show()

# %% [markdown]
# ### The problem is P(A|B), must A=B? And the answer is not, because B can be a subset of A. If the element belongs to B then the element belongs to A necessarely.
